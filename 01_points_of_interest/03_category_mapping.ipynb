# %%
import pandas as pd

# %%
def map_to_group(value):
    for group, items in mapping.items():
        if value in items:
            return group
    return None  # or a default value if no match

# %%
mapping = {
  "Jobs, Professional Services & Religious": [
    "professional_services",
    "community_services_non_profits",
    "construction_services",
    "real_estate",
    "event_planning",
    "church_cathedral",
    "furniture_assembly",
    "software_development",
    "public_and_government_association",
    "information_technology_company",
    "real_estate_agent",
    "advertising_agency",
    "industrial_equipment",
    "parking",
    "physical_therapy",
    "dentist",
    "religious_organization",
    "accountant",
    "print_media",
    "lawyer",
    "business_management_services",
    "engineering_services",
    "home_cleaning",
    "public_service_and_government",
    "social_service_organizations",
    "interior_design",
    "internet_service_provider",
    "financial_service",
    "home_developer",
    "automotive_repair",
    "health_and_medical",
    "architectural_designer",
    "freight_and_cargo_service",
    "marketing_agency",
    "broadcasting_media_production",
    "driving_school",
    "bank_credit_union",
    "central_government_office",
    "event_photography",
    "veterinarian",
    "business_advertising",
    "embassy",
    "hvac_services",
    "property_management",
    "industrial_company",
    "shipping_center",
    "graphic_designer",
    "community_center",
    "contractor",
    "auto_company",
    "real_estate_service",
    "commercial_industrial",
    "computer_hardware_company",
    "non_governmental_association",
    "topic_publisher",
    "electrician",
    "marketing_consultant",
    "automotive_dealer",
    "home_health_care",
    "post_office",
    "fire_department",
    "movie_television_studio",
    "home_service",
    "car_rental_agency",
    "tire_dealer_and_repair",
    "commercial_real_estate",
    "printing_services",
    "telecommunications_company",
    "taxi_service",
    "inspection_services",
    "lawyers",
    "government_offices",
    "marketing",
    "security_systems",
    "corporate_office",
    "pharmaceutical_companies",
    "prenatal_perinatal_care",
    "occupational_therapy",
    "divorce_and_family_law",
    "consultant_and_general_service",
    "professional_sports_team",
    "business_to_business_services",
    "environmental_and_ecological_services_for_businesses",
    "ambulance_and_ems_services",
    "massage_school",
    "osteopathic_physician",
    "business",
    "fire_protection_service",
    "patent_law",
    "media_agency",
    "automation_services",
    "civil_engineers",
    "tax_services",
    "collection_agencies",
    "local_and_state_government_offices",
    "structural_engineer",
    "public_health_clinic",
    "janitorial_services",
    "housing_authorities",
    "health_department",
    "abuse_and_addiction_treatment",
    "foster_care_services",
    "energy_management_and_conservation_consultants",
    "home_inspector",
    "federal_government_offices",
    "tax_law",
    "hearing_aids",
    "career_counseling",
    "secretarial_services",
    "it_consultant",
    "traffic_school",
    "real_estate_law",
    "electricity_supplier",
    "employment_law",
    "business_brokers",
    "data_recovery",
    "criminal_defense_law",
    "department_of_motor_vehicles",
    "health_insurance_office",
    "board_of_education_offices",
    "public_transportation",
    "paralegal_services",
    "appraisal_services",
    "human_resource_services",
    "religious_school",
    "hindu_temple",
    "buddhist_temple",
    "sikh_temple",
    "temple",
    "baptist_church",
    "plastic_fabrication_company",
    "landscape_architect",
    "demolition_service",
    "flooring_contractors",
    "elevator_service",
    "railroad_freight",
    "plastic_fabrication_company",
    "logging_services",
    "insulation_installation",
    "bathroom_remodeling",
    "home_organization",
    "bath_and_sink_repairs",
    "boat_service_and_repair",
    "prenatal_perinatal_care",
    "obstetrician_and_gynecologist",
    "allergist",
    "pediatrician",
    "audiologist",
    "periodontist",
    "orthodontist",
    "clinical_laboratories",
    "laboratory_equipment_supplier", 'senior_citizen_services', 'surgical_center', 'cleaning_services', 
    'dog_groomer', 'pet_sitting', 'dog_walkers',
    'web_designer', 'b2b_science_and_technology', 'b2b_textiles', 'mass_media', 'charity_organization', 
    'engine_repair_service', 'laboratory_testing', 'wholesaler', 'insurance_agency', 'employment_agencies', 
    'energy_company', 'merchandising_service', 'media_news_company', 'international_business_and_trade_services', 
    'business_to_business', 'rental_service', 'it_service_and_computer_repair', 'organization', 'roofing', 
    'recycling_center', 'courier_and_delivery_services', 'public_relations','nurse_practitioner', 'general_dentistry',
    'business_consulting', 'freight_forwarding_agency', 'copywriting_service', 'political_organization', 
    'political_party_office', 'legal_services', 'internet_marketing_service', 'medical_research_and_development', 
    'audiovisual_equipment_rental', 'rental_services', 'food_beverage_service_distribution', 'social_media_agency', 
    'b2b_electronic_equipment', 'car_inspector', 'armed_forces_branch', 'medical_center', 'surgical_appliances_and_supplies', 
    'social_and_human_services', 'private_association', 'public_utility_company', 'appliance_manufacturer', 
    'pest_control_service', 'chemical_plant', 'construction_management', 'building_contractor', 'exporters', 
    'b2b_oil_and_gas_extraction_and_services', 'agricultural_cooperatives', 'environmental_conservation_organization', 
    'video_film_production', 'distribution_services', 'party_and_event_planning', 'garbage_collection_service', 
    'travel_company', 'security_services', 'psychic', 'television_service_providers', 'telecommunications','travel_agents',
    'publicity_service', 'b2b_equipment_maintenance_and_repair', 'metal_materials_and_experts', 'masonry_concrete', 
    'metal_fabricator', 'printing_equipment_and_supply', 'b2b_cleaning_and_waste_management', 'audio_visual_production_and_design', 
    'paving_contractor', 'livestock_breeder', 'iron_and_steel_industry', 'steel_fabricators', 'printing_equipment_and_supply', 
    'professional_sports_league', 'translation_services', 'mortgage_broker', 'executive_search_consultants', 'government_services', 
    'credit_union', 'b2b_jewelers', 'hotel_supply_service', 'art_restoration', 'home_security', 'real_estate_investment', 
    'emergency_room', 'nurse_practitioner', 'occupational_safety', 'trusts', 'commissioned_artist', 'road_contractor', 
    'vehicle_shipping', 'mortgage_lender', 'civic_center', 'aircraft_manufacturer', 'blood_and_plasma_donation_center', 
    'mortgage_lender', 'credit_union', 'executive_search_consultants', 'financial_advising', 'business_consulting', 'lawyer', 
    'courthouse', 'jail_and_prison', 'fire_and_water_damage_restoration', 'eye_care_clinic', 'orthopedics', 'cosmetic_surgeon',
    'town_hall', 'court_house', 'mosque', 'catholic_church', 'evangelical_church', 'pentecostal_church', 'jehovahs_witness_kingdom_hall',
    'convents_and_monasteries', 'doctor', 'optometrist', 'plastic_surgeon','prosthodontist', 'pediatric_dentist',
    "damage_restoration",
    "motor_freight_trucking",
    "warehouses",
    "carpenter",
    "youth_organizations",
    "translating_and_interpreting_services",
    "hvac_supplier",
    "labor_union",
    "auto_glass_service",
    "funeral_services_and_cemeteries",
    "key_and_locksmith",
    "plumbing",
    "motorcycle_repair",
    "used_car_dealer",
    "auto_electrical_repair",
    "car_wash",
    "boat_rental_and_training",
    "importers",
    "investing",
    "architect",
    "shoe_repair",
    "biotechnology_company",
    "builder",
    "auction_house",
    "videographer",
    "environmental_conservation_and_ecological_organizations",
    "mining",
    "airline",
    "fireplace_service",
    "agriculture",
    "land_surveying",
    "forestry_service",
    "landscaping",
    "gardener",
    "tree_services",
    "chimney_sweep",
    "emissions_inspection",
    "natural_gas_supplier",
    "hydraulic_equipment_supplier",
    "boat_dealer",
    "boat_parts_and_accessories",
    "recreational_vehicle_dealer",
    "movers",
    "cremation_services",
    "housing_cooperative",
    "homeless_shelter",
    "coworking_space",
    "radio_and_television_commercials",
    "automotive_consultant",
    "electric_utility_provider",
    "tiling",
    "countertop_installation",
    "radio_station",
    "bookkeeper",
    "media_news_website",
    "energy_equipment_and_solution",
    "b2b_truck_equipment_parts_and_accessories",
    "water_supplier",
    "ev_charging_station",
    "awning_supplier",
    "cement_supplier",
    "glass_manufacturer",
    "plastic_manufacturer",
    "wheel_and_rim_repair",
    "digitizing_services",
    "auto_restoration_services",
    "piano_services",
    "farm_equipment_and_supply",
    "gold_buyer",
    "bartender",
    "airlines",
    "excavations_service",
    "wedding_planning",
    "religious",
    "pet_groomer",
    "dog_trainer",
    "horse_trainer",
    "taxidermist",
    "podiatrist",
    "ophthalmologist",
    'architect'
    "oral_surgeon",
    "maternity_centers"
],

  "Shopping & Retail": [
    "shopping",
    "clothing_store",
    "online_shop",
    "fashion",
    "furniture_store",
    "flowers_and_gifts_shop",
    "women's_clothing_store",
    "auto_detailing",
    "shopping_center",
    "sporting_goods",
    "home_improvement_store",
    "cosmetic_and_beauty_supplies",
    "jewelry_store",
    "bicycle_shop",
    "pet_services",
    "eyewear_and_optician",
    "building_supply_store",
    "automotive_parts_and_accessories",
    "electronics",
    "hardware_store",
    "retail",
    "bookstore",
    "sewing_and_alterations",
    "men's_clothing_store",
    "flea_market",
    "shoe_store",
    "department_store",
    "mobile_phone_store",
    "musical_instrument_store",
    "lighting_store",
    "antique_store",
    "liquor_store",
    "pet_store",
    "used_vintage_and_consignment",
    "fabric_store",
    "electrical_supply_store",
    "pop_up_shop",
    "fishmonger",
    "kitchen_supply_store",
    "lingerie_store",
    "screen_printing_t_shirt_printing",
    "sign_making",
    "restaurant_equipment_and_supply",
    "furniture_manufacturers",
    "dry_cleaning",
    "ski_and_snowboard_shop",
    "lumber_store",
    "outdoor_gear",
    "farmers_market",
    "chocolatier",
    "appliance_repair_service",
    "machine_shop",
    "pawn_shop",
    "jewelry_and_watches_manufacturer",
    "sand_and_gravel_supplier",
    "paint_store",
    "solar_installation",
    "e_cigarette_store",
    "brake_service_and_repair",
    "dental_supply_store",
    "paintball",
    "video_game_store",
    "pharmaceutical_products_wholesaler",
    "glass_and_mirror_sales_service",
    "auto_manufacturers_and_distributors",
    "rug_store",
    "luggage_store",
    "electronic_parts_supplier",
    "home_decor",
    "windows_installation",
    "aquatic_pet_store",
    "automotive_services_and_repair",
    "b2b_food_products",
    "business_office_supplies_and_stationery",
    "woodworking_supply_store",
    "metal_supplier",
    "comic_books_store",
    "packing_supply",
    "laundromat",
    "paper_mill",
    "canoe_and_kayak_hire_service",
    "oil_and_gas_field_equipment_and_services",
    "masonry_contractors",
    "costume_store",
    "wig_store",
    "scuba_diving_center",
    "book_magazine_distribution",
    "hunting_and_fishing_supplies",
    "wood_and_pulp",
    "tile_store",
    "bottled_water_company",
    "framing_store",
    "commercial_printer",
    "pet_breeder",
    "toy_store",
    "motorsports_store",
    "auto_upholstery",
    "patio_covers",
    "welding_supply_store",
    "truck_repair",
    "music_and_dvd_store",
    "deck_and_railing_sales_service",
    "truck_rentals",
    "leather_goods",
    "superstore",
    "commercial_refrigeration",
    "motorsport_vehicle_dealer",
    "propane_supplier",
    "trailer_rentals",
    "cards_and_stationery_store",
    "fertilizer_store",
    "awnings_and_blinds",
    "fabric_wholesaler",
    "yard_and_equipment_sales",
    "mobile_phone_repair",
    "rv_park",
    "outlet_store",
    "junk_removal_and_hauling",
    "junkyard",
    "logging_equipment_and_supplies",
    "e_commerce_service",
    "fence_and_gate_sales_service",
    "trailer_dealer",
    "machine_and_tool_rentals",
    "promotional_products_and_services",
    "car_window_tinting",
    "metals",
    "truck_dealer",
    "dental_supply_store",
    "heliports",
    "furniture_repair",
    "hat_shop",
    "window_treatment_store",
    "tools_wholesaler",
    "mattress_store",
    "candy_store",
    "logging_equipment_and_supplies",
    'perfume_store',
    "thrift_store",
    "fashion_accessories_store",
    "children's_clothing_store",
    "photography_store_and_services",
    "home_goods_store",
    "audio_visual_equipment_store",
    "boutique",
    "storage_facility",
    "self_storage_facility",
    "motorcycle_dealer",
    "carpet_store",
    "appliance_store",
    "computer_store",
    "auto_parts_and_supply_store",
    "auto_customization",
    "office_equipment",
    "discount_store",
    "florist",
    "bridal_shop",
    "vitamins_and_supplements",
    "sunglasses_store",
    "clothing_company",
    "sports_wear",
    "gift_shop",
    "books_mags_music_and_video",
    "custom_clothing",
    "hobby_shop",
    "home_and_garden",
    "swimwear_store",
    "newspaper_and_magazines_store",
    "pets",
    "stone_and_masonry",
    "souvenir_shop",
    "custom_t_shirt_store",
    "shades_and_blinds",
    "luggage_storage",
    "tire_shop",
    "reptile_shop",
    "home_theater_systems_stores",
    "skate_shop",
    "b2b_apparel"
  ],

  "Restaurant & Entertainment": [
    "restaurant",
    "cafe",
    "bar",
    "pizza_restaurant",
    "coffee_shop",
    "topic_concert_venue",
    "accommodation",
    "arts_and_entertainment",
    "theatre",
    "pub",
    "sushi_restaurant",
    "bakery",
    'library', 'cultural_center', 
    "burger_restaurant",
    "fast_food_restaurant",
    "sports_and_recreation_venue",
    "museum",
    "attractions_and_activities",
    "travel",
    "arts_and_crafts",
    "italian_restaurant",
    "pool_billiards",
    "chinese_restaurant",
    "travel_services",
    "music_production",
    "music_venue",
    "dance_club",
    "thai_restaurant",
    "sandwich_shop",
    "buffet_restaurant",
    "cinema",
    "himalayan_nepalese_restaurant",
    "golf_course",
    "caterer",
    "choir",
    "cafetaria",
    "art_museum",
    "eat_and_drink",
    "mexican_restaurant",
    "winery",
    "karaoke",
    "asian_restaurant",
    "japanese_restaurant",
    "indian_restaurant",
    "marina",
    "tours",
    "georgian_restaurant",
    "beer_bar",
    "smoothie_juice_bar",
    "ice_cream_shop",
    "doner_kebab",
    "greek_restaurant",
    "korean_restaurant",
    "salad_bar",
    "french_restaurant",
    "mediterranean_restaurant",
    "jazz_and_blues",
    "irish_pub",
    'art_gallery',
    "american_restaurant",
    "asian_fusion_restaurant",
    "soup_restaurant",
    "lebanese_restaurant",
    "restaurant_wholesale",
    "tapas_bar",
    "desserts",
    "food_stand",
    "hot_dog_restaurant",
    'portuguese_restaurant',
    "arcade",
    "comedy_club",
    "theatrical_productions",
    "hotel_bar",
    "food_delivery_service",
    "food_truck",
    "halal_restaurant",
    "spanish_restaurant",
    "persian_iranian_restaurant",
    "filipino_restaurant",
    "falafel_restaurant",
    "malaysian_restaurant",
    "texmex_restaurant",
    "comfort_food_restaurant",
    "russian_restaurant",
    "noodles_restaurant",
    "poke",
    "donuts",
    "ice_cream_and_frozen_yoghurt",
    "gelato",
    "hawaiian_restaurant",
    "painting",
    "sports_bar",
    "distillery",
    "sports_museum",
    "whiskey_bar",
    "coffee_roastery",
    "sake_bar",
    "afghan_restaurant",
    "german_restaurant",
    "czech_restaurant",
    "taco_restaurant",
    "kurdish_restaurant",
    "egyptian_restaurant",
    "peruvian_restaurant",
    "ukrainian_restaurant",
    "latin_american_restaurant",
    "syrian_restaurant",
    "indonesian_restaurant",
    "dim_sum_restaurant",
    "cupcake_shop",
    "science_museum",
    "civilization_museum",
    "history_museum",
    "gay_bar",
    "stadium_arena",
    "circus", "go_kart_club",
    "landmark_and_historical_building",
    "planetarium", 'vegetarian_restaurant', 'casino', 'wine_bar', 'bar_and_grill_restaurant', 
    'scandinavian_restaurant', 'cocktail_bar', 
    'breakfast_and_brunch_restaurant', 'vietnamese_restaurant', 'delicatessen', 
    'brewery', 'european_restaurant', 'barbecue_restaurant', 
    'ice_skating_rink', 'diner', 'seafood_restaurant', 'steakhouse', 'bubble_tea',
    'turkish_restaurant', 'chicken_restaurant', 'middle_eastern_restaurant', 
    'beer_garden', 'gastropub', 'lounge', 'tea_room', 'restaurant', 
    'fast_food', 'cafe', 'food_court', 'night_club', 'bowling_alley', 'arcade', 
    'amusement_park', 'water_park', 'miniature_golf_course', 'ski_resort', 'resort',
    'hostel', 'campground', 'movie_theater', 'opera_and_ballet', 
    'theaters_and_performance_venues', 'concert_hall', 'music_venue', 'dance_club', 
    'karaoke_bar', 'escape_rooms', 'video_game_arcade', 'party_and_event_planning',
    'party_supply', 'dinner_theater', 'food_tours', 'food_and_beverage_consultant', 
    'food'
  ],

  "Well-being & Lifestyle": [
    "beauty_salon",
    "spas",
    "gym",
    "park",
    "hospital",
    "barber",
    "day_care_preschool",
    "sports_club_and_league",
    "beauty_and_spa",
    "retirement_home",
    "pharmacy",
    "public_plaza",
    "naturopathic_holistic",
    "yoga_studio",
    "dance_school",
    "music_school",
    "pilates_studio",
    "counseling_and_mental_health",
    "fitness_trainer",
    "chiropractor",
    "meditation_center",
    "medical_supply",
    "medical_service_organizations",
    "occupational_therapy",
    "pet_boarding",
    "tanning_salon",
    "massage_therapy",
    "weight_loss_center",
    "nutritionist",
    "swimming_instructor",
    "massage_school",
    "reflexology",
    "bike_rentals",
    "piercing",
    "psychiatrist",
    "hair_removal",
    'skate_park',
    "nail_salon",
    "sugaring",
    "personal_care_service",
    "makeup_artist",
    "dog_park",
    "paddleboarding_center",
    "medical_spa",
    "aromatherapy",
    "tattoo_and_piercing",
    "osteopath",
    "scuba_diving_instruction",
    "alternative_medicine",
    "sex_therapist",
    "foot_care",
    "equestrian_facility",
    "health_market",
    "family_practice", 
    'martial_arts_club', 
    'assisted_living_facility', 
    "active_life",
    'psychologist', 
    "national_park",
    'life_coach', 'massage', 'hair_salon', 
    'acupuncture',
    'psychotherapist', 
    'cosmetic_dentist', 
    "rock_climbing_spot",
    'speech_therapist', 
    'alcohol_and_drug_treatment_centers', 
    'acupuncture', 'hair_stylist', 
    'disability_services_and_support_organization', 'beauty_product_supplier', 'massage', 'well_drilling', 
    'swimming_pool',
    "surfing",
    "hiking_trail",
    'sauna', 'gymnastics_center', 'sports_and_fitness_instruction',
    'hair_supply_stores', 'fitness_center', 'yoga_studio', 'wellness_center', 'spa',
    "tennis_court",
    "soccer_stadium",
    "hockey_arena",
    "disc_golf_course",
    "soccer_field",
    "playground",
    "basketball_court",
    "baseball_field",
    "racquetball_court",
    "squash_court",
  ],

  "Educational Facilities": [
    "school",
    "college_university",
    "elementary_school",
    "education",
    "preschool",
    "campus_building",
    "high_school",
    "public_school",
    "private_school",
    "flight_school",
    "university",
    "college",
    "preschool",
    "education_buildings",
    "cooking_school",
    "middle_school",
    "educational_research_institute",
    "first_aid_class",
    "educational_camp",
    "computer_coaching",
    "writing_service",
    "medical_school",
    "bartending_school",
    "child_care_and_day_care",
    "educational_services",
    "sports_psychologist",
    'nursery_and_gardening', 'tutoring_center', 
    'language_school', 'art_school', 'specialty_school', 'vocational_and_technical_school'
  
  ],

  "Grocery Stores & Supermarkets": [
    "grocery_store",
    "supermarket",
    "wholesale_store",
    "convenience_store",
    "butcher_shop",
    "grocery_stores",
    "supermarkets",
    "convenience_stores",
    "wholesale_stores",
    "farmers_market",
    "fruits_and_vegetables",
    "ethical_grocery",
    "cheese_shop",
    "specialty_grocery_store",
    "wholesale_grocer",
    "produce_wholesaler",
    "beverage_supplier",
    'health_food_store',
    "organic_grocery_store",
    'korean_grocery_store',
    "pasta_shop",
    "korean_grocery_store"
  ],

  "Uncategorized": [
    "transportation",
    "hotel",
    "gas_station",
    "beach",
    "atms",
    "car_dealer",
    "automotive",
    "train_station",
    "lake",
    "structure_and_geography",
    "airport",
    "river",
    "monument",
    "nature_reserve",
    "cottage",
    "bridge",
    "currency_exchange",
    "water_treatment_equipment_and_services",
    "zoo",
    "race_track",
    "kids_recreation_and_party",
    "apartments",
    "ferry_boat_company",
    "wildlife_sanctuary",
    "b2b_food_products",
    "heliports",
    "oil_and_gas_field_equipment_and_services",
    "rv_park",
    "logging_services",
    "junkyard",
    "junk_removal_and_hauling",
    "e_commerce_service",
    "promotional_products_and_services",
    'airport_lounge',
    'public_toilet', 
    'airport_terminal',
    'armed_forces_branch', 
    'police_department',
    'food_safety_training',
    "holiday_rental_home",
    "service_apartments",
    "bed_and_breakfast",
    "lodge",
    "cave"  
  ]}

# %%
import json


with open("./data/category_mapping.json", "w", encoding="utf-8") as f:
    json.dump(mapping, f, indent=4, ensure_ascii=False)

# %%
# Load CSV
df = pd.read_csv("./data/category_list.csv")

# Column to compare
csv_values = df['primary'].astype(str).unique()  # adjust column name

# Convert the list to a set for faster lookup
my_set = set(my_list)

# Find those in CSV but not in the list
not_in_list = [val for val in csv_values if val not in my_set]

print("Values in CSV but not in list:")
print(not_in_list)

# %%
my_list = [
    "professional_services",
    "community_services_non_profits",
    "construction_services",
    "real_estate",
    "event_planning",
    "church_cathedral",
    "software_development",
    "public_and_government_association",
    "information_technology_company",
    "real_estate_agent",
    "advertising_agency",
    "industrial_equipment",
    "parking",
    "physical_therapy",
    "dentist",
    "religious_organization",
    "accountant",
    "lawyer",
    "business_management_services",
    "engineering_services",
    "home_cleaning",
    "public_service_and_government",
    "social_service_organizations",
    "interior_design",
    "internet_service_provider",
    "financial_service",
    "home_developer",
    "automotive_repair",
    "health_and_medical",
    "architectural_designer",
    "freight_and_cargo_service",
    "marketing_agency",
    "broadcasting_media_production",
    "driving_school",
    "bank_credit_union",
    "central_government_office",
    "event_photography",
    "veterinarian",
    "business_advertising",
    "embassy",
    "hvac_services",
    "property_management",
    "industrial_company",
    "shipping_center",
    "graphic_designer",
    "community_center",
    "contractor",
    "auto_company",
    "real_estate_service",
    "commercial_industrial",
    "computer_hardware_company",
    "non_governmental_association",
    "topic_publisher",
    "electrician",
    "marketing_consultant",
    "automotive_dealer",
    "home_health_care",
    "post_office",
    "fire_department",
    "movie_television_studio",
    "home_service",
    "car_rental_agency",
    "tire_dealer_and_repair",
    "commercial_real_estate",
    "printing_services",
    "telecommunications_company",
    "taxi_service",
    "inspection_services",
    "lawyers",
    "government_offices",
    "marketing",
    "security_systems",
    "corporate_office",
    "pharmaceutical_companies",
    "prenatal_perinatal_care",
    "occupational_therapy",
    "divorce_and_family_law",
    "consultant_and_general_service",
    "professional_sports_team",
    "business_to_business_services",
    "environmental_and_ecological_services_for_businesses",
    "ambulance_and_ems_services",
    "massage_school",
    "osteopathic_physician",
    "business",
    "fire_protection_service",
    "patent_law",
    "media_agency",
    "automation_services",
    "civil_engineers",
    "tax_services",
    "collection_agencies",
    "local_and_state_government_offices",
    "structural_engineer",
    "public_health_clinic",
    "janitorial_services",
    "housing_authorities",
    "health_department",
    "abuse_and_addiction_treatment",
    "foster_care_services",
    "energy_management_and_conservation_consultants",
    "home_inspector",
    "federal_government_offices",
    "tax_law",
    "hearing_aids",
    "career_counseling",
    "secretarial_services",
    "it_consultant",
    "traffic_school",
    "real_estate_law",
    "electricity_supplier",
    "employment_law",
    "business_brokers",
    "data_recovery",
    "criminal_defense_law",
    "department_of_motor_vehicles",
    "health_insurance_office",
    "board_of_education_offices",
    "public_transportation",
    "paralegal_services",
    "appraisal_services",
    "human_resource_services",
    "religious_school",
    "hindu_temple",
    "buddhist_temple",
    "sikh_temple",
    "temple",
    "baptist_church",
    "plastic_fabrication_company",
    "landscape_architect",
    "demolition_service",
    "flooring_contractors",
    "elevator_service",
    "railroad_freight",
    "plastic_fabrication_company",
    "logging_services",
    "insulation_installation",
    "bathroom_remodeling",
    "home_organization",
    "bath_and_sink_repairs",
    "boat_service_and_repair",
    "prenatal_perinatal_care",
    "obstetrician_and_gynecologist",
    "allergist",
    "pediatrician",
    "audiologist",
    "periodontist",
    "orthodontist",
    "clinical_laboratories",
    "laboratory_equipment_supplier", 'senior_citizen_services', 'surgical_center', 'cleaning_services', 
    'dog_groomer', 'pet_sitting', 'dog_walkers',
    'web_designer', 'b2b_science_and_technology', 'b2b_textiles', 'mass_media', 'charity_organization', 
    'engine_repair_service', 'laboratory_testing', 'wholesaler', 'insurance_agency', 'employment_agencies', 
    'energy_company', 'merchandising_service', 'media_news_company', 'international_business_and_trade_services', 
    'business_to_business', 'rental_service', 'it_service_and_computer_repair', 'organization', 'roofing', 
    'recycling_center', 'courier_and_delivery_services', 'public_relations','nurse_practitioner', 'general_dentistry',
    'business_consulting', 'freight_forwarding_agency', 'copywriting_service', 'political_organization', 
    'political_party_office', 'legal_services', 'internet_marketing_service', 'medical_research_and_development', 
    'audiovisual_equipment_rental', 'rental_services', 'food_beverage_service_distribution', 'social_media_agency', 
    'b2b_electronic_equipment', 'car_inspector', 'armed_forces_branch', 'medical_center', 'surgical_appliances_and_supplies', 
    'social_and_human_services', 'private_association', 'public_utility_company', 'appliance_manufacturer', 
    'pest_control_service', 'chemical_plant', 'construction_management', 'building_contractor', 'exporters', 
    'b2b_oil_and_gas_extraction_and_services', 'agricultural_cooperatives', 'environmental_conservation_organization', 
    'video_film_production', 'distribution_services', 'party_and_event_planning', 'garbage_collection_service', 
    'travel_company', 'security_services', 'psychic', 'television_service_providers', 'telecommunications','travel_agents',
    'publicity_service', 'b2b_equipment_maintenance_and_repair', 'metal_materials_and_experts', 'masonry_concrete', 
    'metal_fabricator', 'printing_equipment_and_supply', 'b2b_cleaning_and_waste_management', 'audio_visual_production_and_design', 
    'paving_contractor', 'livestock_breeder', 'iron_and_steel_industry', 'steel_fabricators', 'printing_equipment_and_supply', 
    'professional_sports_league', 'translation_services', 'mortgage_broker', 'executive_search_consultants', 'government_services', 
    'credit_union', 'b2b_jewelers', 'hotel_supply_service', 'art_restoration', 'home_security', 'real_estate_investment', 
    'emergency_room', 'nurse_practitioner', 'occupational_safety', 'trusts', 'commissioned_artist', 'road_contractor', 
    'vehicle_shipping', 'mortgage_lender', 'civic_center', 'aircraft_manufacturer', 'blood_and_plasma_donation_center', 
    'mortgage_lender', 'credit_union', 'executive_search_consultants', 'financial_advising', 'business_consulting', 'lawyer', 
    'courthouse', 'jail_and_prison', 'fire_and_water_damage_restoration', 'eye_care_clinic', 'orthopedics', 'cosmetic_surgeon',
    'town_hall', 'court_house', 'mosque', 'catholic_church', 'evangelical_church', 'pentecostal_church', 'jehovahs_witness_kingdom_hall',
    'convents_and_monasteries', 'doctor', 'optometrist', 'plastic_surgeon','prosthodontist', 'pediatric_dentist',
    "damage_restoration",
    "motor_freight_trucking",
    "warehouses",
    "carpenter",
    "translating_and_interpreting_services",
    "hvac_supplier",
    "labor_union",
    "auto_glass_service",
    "funeral_services_and_cemeteries",
    "key_and_locksmith",
    "plumbing",
    "motorcycle_repair",
    "used_car_dealer",
    "auto_electrical_repair",
    "car_wash",
    "boat_rental_and_training",
    "importers",
    "investing",
    "biotechnology_company",
    "builder",
    "auction_house",
    "videographer",
    "environmental_conservation_and_ecological_organizations",
    "mining",
    "airline",
    "fireplace_service",
    "agriculture",
    "land_surveying",
    "forestry_service",
    "landscaping",
    "gardener",
    "tree_services",
    "chimney_sweep",
    "emissions_inspection",
    "natural_gas_supplier",
    "hydraulic_equipment_supplier",
    "boat_dealer",
    "boat_parts_and_accessories",
    "recreational_vehicle_dealer",
    "movers",
    "cremation_services",
    "housing_cooperative",
    "homeless_shelter",
    "coworking_space",
    "radio_and_television_commercials",
    "automotive_consultant",
    "electric_utility_provider",
    "tiling",
    "countertop_installation",
    "radio_station",
    "bookkeeper",
    "media_news_website",
    "energy_equipment_and_solution",
    "b2b_truck_equipment_parts_and_accessories",
    "water_supplier",
    "ev_charging_station",
    "awning_supplier",
    "cement_supplier",
    "glass_manufacturer",
    "plastic_manufacturer",
    "wheel_and_rim_repair",
    "digitizing_services",
    "auto_restoration_services",
    "piano_services",
    "farm_equipment_and_supply",
    "gold_buyer",
    "bartender",
    "airlines",
    "excavations_service",
    "wedding_planning",
    "religious",
    "pet_groomer",
    "dog_trainer",
    "horse_trainer",
    "taxidermist",
    "podiatrist",
    "ophthalmologist",
    "oral_surgeon",
    "maternity_centers",
    "tennis_court",
    "soccer_stadium",
    "hockey_arena",
    "playground",
    "basketball_court",
    "baseball_field",
    "racquetball_court",
    "squash_court",
    "shopping",
    "clothing_store",
    "online_shop",
    "fashion",
    "furniture_store",
    "flowers_and_gifts_shop",
    "women's_clothing_store",
    "auto_detailing",
    "shopping_center",
    "sporting_goods",
    "home_improvement_store",
    "cosmetic_and_beauty_supplies",
    "jewelry_store",
    "bicycle_shop",
    "pet_services",
    "eyewear_and_optician",
    "building_supply_store",
    "automotive_parts_and_accessories",
    "electronics",
    "hardware_store",
    "retail",
    "bookstore",
    "sewing_and_alterations",
    "men's_clothing_store",
    "flea_market",
    "shoe_store",
    "department_store",
    "mobile_phone_store",
    "musical_instrument_store",
    "lighting_store",
    "antique_store",
    "liquor_store",
    "pet_store",
    "used_vintage_and_consignment",
    "fabric_store",
    "electrical_supply_store",
    "pop_up_shop",
    "fishmonger",
    "kitchen_supply_store",
    "lingerie_store",
    "screen_printing_t_shirt_printing",
    "sign_making",
    "restaurant_equipment_and_supply",
    "furniture_manufacturers",
    "dry_cleaning",
    "ski_and_snowboard_shop",
    "lumber_store",
    "farmers_market",
    "chocolatier",
    "appliance_repair_service",
    "machine_shop",
    "pawn_shop",
    "jewelry_and_watches_manufacturer",
    "sand_and_gravel_supplier",
    "paint_store",
    "solar_installation",
    "e_cigarette_store",
    "brake_service_and_repair",
    "dental_supply_store",
    "paintball",
    "video_game_store",
    "pharmaceutical_products_wholesaler",
    "glass_and_mirror_sales_service",
    "auto_manufacturers_and_distributors",
    "rug_store",
    "luggage_store",
    "electronic_parts_supplier",
    "home_decor",
    "windows_installation",
    "aquatic_pet_store",
    "automotive_services_and_repair",
    "b2b_food_products",
    "business_office_supplies_and_stationery",
    "woodworking_supply_store",
    "metal_supplier",
    "comic_books_store",
    "packing_supply",
    "laundromat",
    "paper_mill",
    "canoe_and_kayak_hire_service",
    "oil_and_gas_field_equipment_and_services",
    "masonry_contractors",
    "costume_store",
    "wig_store",
    "scuba_diving_center",
    "book_magazine_distribution",
    "hunting_and_fishing_supplies",
    "wood_and_pulp",
    "tile_store",
    "bottled_water_company",
    "framing_store",
    "commercial_printer",
    "pet_breeder",
    "toy_store",
    "motorsports_store",
    "auto_upholstery",
    "patio_covers",
    "welding_supply_store",
    "truck_repair",
    "deck_and_railing_sales_service",
    "truck_rentals",
    "leather_goods",
    "superstore",
    "commercial_refrigeration",
    "motorsport_vehicle_dealer",
    "propane_supplier",
    "trailer_rentals",
    "cards_and_stationery_store",
    "fertilizer_store",
    "awnings_and_blinds",
    "fabric_wholesaler",
    "yard_and_equipment_sales",
    "mobile_phone_repair",
    "rv_park",
    "outlet_store",
    "junk_removal_and_hauling",
    "junkyard",
    "logging_equipment_and_supplies",
    "e_commerce_service",
    "fence_and_gate_sales_service",
    "trailer_dealer",
    "machine_and_tool_rentals",
    "promotional_products_and_services",
    "car_window_tinting",
    "metals",
    "truck_dealer",
    "dental_supply_store",
    "heliports",
    "furniture_repair",
    "hat_shop",
    "window_treatment_store",
    "tools_wholesaler",
    "mattress_store",
    "candy_store",
    "logging_equipment_and_supplies",
    'perfume_store',
    "thrift_store",
    "fashion_accessories_store",
    "children's_clothing_store",
    "photography_store_and_services",
    "home_goods_store",
    "audio_visual_equipment_store",
    "boutique",
    "storage_facility",
    "self_storage_facility",
    "motorcycle_dealer",
    "carpet_store",
    "appliance_store",
    "computer_store",
    "auto_parts_and_supply_store",
    "auto_customization",
    "office_equipment",
    "discount_store",
    "florist",
    "bridal_shop",
    "vitamins_and_supplements",
    "sunglasses_store",
    "clothing_company",
    "sports_wear",
    "gift_shop",
    "books_mags_music_and_video",
    "custom_clothing",
    "hobby_shop",
    "home_and_garden",
    "swimwear_store",
    "newspaper_and_magazines_store",
    "pets",
    "stone_and_masonry",
    "souvenir_shop",
    "custom_t_shirt_store",
    "shades_and_blinds",
    "luggage_storage",
    "tire_shop",
    "reptile_shop",
    "home_theater_systems_stores",
    "skate_shop",
    "b2b_apparel",
    "restaurant",
    "cafe",
    "bar",
    "pizza_restaurant",
    "coffee_shop",
    "topic_concert_venue",
    "accommodation",
    "arts_and_entertainment",
    "theatre",
    "pub",
    "sushi_restaurant",
    "bakery",
    'library', 'cultural_center', 
    "burger_restaurant",
    "fast_food_restaurant",
    "sports_and_recreation_venue",
    "museum",
    "attractions_and_activities",
    "travel",
    "arts_and_crafts",
    "italian_restaurant",
    "chinese_restaurant",
    "travel_services",
    "music_production",
    "music_venue",
    "dance_club",
    "thai_restaurant",
    "sandwich_shop",
    "buffet_restaurant",
    "cinema",
    "himalayan_nepalese_restaurant",
    "golf_course",
    "caterer",
    "choir",
    "cafetaria",
    "art_museum",
    "eat_and_drink",
    "mexican_restaurant",
    "karaoke",
    "asian_restaurant",
    "japanese_restaurant",
    "indian_restaurant",
    "marina",
    "tours",
    "beer_bar",
    "smoothie_juice_bar",
    "ice_cream_shop",
    "doner_kebab",
    "greek_restaurant",
    "korean_restaurant",
    "salad_bar",
    "french_restaurant",
    "mediterranean_restaurant",
    "jazz_and_blues",
    "irish_pub",
    'art_gallery',
    "american_restaurant",
    "asian_fusion_restaurant",
    "soup_restaurant",
    "lebanese_restaurant",
    "restaurant_wholesale",
    "tapas_bar",
    "desserts",
    "food_stand",
    "hot_dog_restaurant",
    "arcade",
    "comedy_club",
    "theatrical_productions",
    "hotel_bar",
    "food_delivery_service",
    "food_truck",
    "halal_restaurant",
    "spanish_restaurant",
    "persian_iranian_restaurant",
    "filipino_restaurant",
    "falafel_restaurant",
    "malaysian_restaurant",
    "texmex_restaurant",
    "comfort_food_restaurant",
    "russian_restaurant",
    "noodles_restaurant",
    "poke",
    "donuts",
    "ice_cream_and_frozen_yoghurt",
    "gelato",
    "hawaiian_restaurant",
    "sports_bar",
    "distillery",
    "sports_museum",
    "whiskey_bar",
    "coffee_roastery",
    "sake_bar",
    "afghan_restaurant",
    "german_restaurant",
    "czech_restaurant",
    "taco_restaurant",
    "egyptian_restaurant",
    "peruvian_restaurant",
    "ukrainian_restaurant",
    "latin_american_restaurant",
    "syrian_restaurant",
    "indonesian_restaurant",
    "dim_sum_restaurant",
    "cupcake_shop",
    "science_museum",
    "civilization_museum",
    "history_museum",
    "gay_bar",
    "stadium_arena",
    "circus",
    "landmark_and_historical_building",
    "planetarium", 'vegetarian_restaurant', 'casino', 'wine_bar', 'bar_and_grill_restaurant', 
    'scandinavian_restaurant', 'cocktail_bar', 
    'breakfast_and_brunch_restaurant', 'vietnamese_restaurant', 'delicatessen', 
    'brewery', 'european_restaurant', 'barbecue_restaurant', 
    'ice_skating_rink', 'diner', 'seafood_restaurant', 'steakhouse', 'bubble_tea',
    'turkish_restaurant', 'chicken_restaurant', 'middle_eastern_restaurant', 
    'beer_garden', 'gastropub', 'lounge', 'tea_room', 'restaurant', 
    'fast_food', 'cafe', 'food_court', 'night_club', 'bowling_alley', 'arcade', 
    'amusement_park', 'water_park', 'miniature_golf_course', 'ski_resort', 'resort',
    'hostel', 'campground', 'movie_theater', 'opera_and_ballet', 
    'theaters_and_performance_venues', 'concert_hall', 'music_venue', 'dance_club', 
    'karaoke_bar', 'escape_rooms', 'video_game_arcade', 'party_and_event_planning',
    'party_supply', 'dinner_theater', 'food_tours', 'food_and_beverage_consultant', 
    'food',
    "beauty_salon",
    "spas",
    "gym",
    "park",
    "hospital",
    "barber",
    "day_care_preschool",
    "sports_club_and_league",
    "beauty_and_spa",
    "retirement_home",
    "pharmacy",
    "public_plaza",
    "naturopathic_holistic",
    "yoga_studio",
    "dance_school",
    "music_school",
    "pilates_studio",
    "counseling_and_mental_health",
    "fitness_trainer",
    "chiropractor",
    "meditation_center",
    "medical_supply",
    "medical_service_organizations",
    "occupational_therapy",
    "pet_boarding",
    "tanning_salon",
    "massage_therapy",
    "weight_loss_center",
    "nutritionist",
    "swimming_instructor",
    "massage_school",
    "reflexology",
    "bike_rentals",
    "piercing",
    "psychiatrist",
    "hair_removal",
    "nail_salon",
    "sugaring",
    "personal_care_service",
    "makeup_artist",
    "medical_spa",
    "aromatherapy",
    "tattoo_and_piercing",
    "osteopath",
    "scuba_diving_instruction",
    "alternative_medicine",
    "sex_therapist",
    "foot_care",
    "health_market",
    "family_practice", 
    'martial_arts_club', 
    'assisted_living_facility', 
    'psychologist', 
    'life_coach', 'massage', 'hair_salon', 
    'acupuncture',
    'psychotherapist', 
    'cosmetic_dentist',  
    'speech_therapist', 
    'alcohol_and_drug_treatment_centers', 
    'acupuncture', 'hair_stylist', 
    'disability_services_and_support_organization', 'beauty_product_supplier', 'massage', 'well_drilling', 
    'swimming_pool',
    'sauna', 'gymnastics_center', 'sports_and_fitness_instruction',
    'hair_supply_stores', 'fitness_center', 'yoga_studio', 'wellness_center', 'spa',
    "school",
    "college_university",
    "elementary_school",
    "education",
    "preschool",
    "campus_building",
    "high_school",
    "public_school",
    "private_school",
    "flight_school",
    "university",
    "college",
    "preschool",
    "education_buildings",
    "cooking_school"
    "middle_school",
    "educational_research_institute",
    "first_aid_class",
    "educational_camp",
    "computer_coaching",
    "writing_service",
    "medical_school",
    "bartending_school",
    "child_care_and_day_care",
    "educational_services",
    "sports_psychologist",
    'nursery_and_gardening', 'tutoring_center', 
    'language_school', 'art_school', 'specialty_school', 'vocational_and_technical_school',
    "grocery_store",
    "supermarket",
    "wholesale_store",
    "convenience_store",
    "butcher_shop",
    "grocery_stores",
    "supermarkets",
    "convenience_stores",
    "wholesale_stores",
    "farmers_market",
    "fruits_and_vegetables",
    "ethical_grocery",
    "cheese_shop",
    "specialty_grocery_store",
    "wholesale_grocer",
    "produce_wholesaler",
    "beverage_supplier",
    'health_food_store',
    "organic_grocery_store"
    'korean_grocery_store',
    "pasta_shop",
    "transportation",
    "hotel",
    "gas_station",
    "beach",
    "atms",
    "car_dealer",
    "automotive",
    "train_station",
    "lake",
    "structure_and_geography",
    "airport",
    "river",
    "monument",
    "nature_reserve",
    "cottage",
    "bridge",
    "currency_exchange",
    "water_treatment_equipment_and_services",
    "zoo",
    "race_track",
    "kids_recreation_and_party",
    "apartments",
    "ferry_boat_company",
    "wildlife_sanctuary",
    "b2b_food_products",
    "heliports",
    "oil_and_gas_field_equipment_and_services",
    "rv_park",
    "logging_services",
    "junkyard",
    "junk_removal_and_hauling",
    "e_commerce_service",
    "promotional_products_and_services",
    'airport_lounge',
    'public_toilet', 
    'airport_terminal',
    'armed_forces_branch', 
    'police_department',
    'food_safety_training',
    "holiday_rental_home",
    "service_apartments",
    "bed_and_breakfast",
    "lodge",
    "cave"

]

# %%
mapping = {
  "Jobs, Professional Services & Religious": [
    "professional_services",
    "community_services_non_profits",
    "construction_services",
    "real_estate",
    "event_planning",
    "church_cathedral",
    "furniture_assembly",
    "software_development",
    "public_and_government_association",
    "information_technology_company",
    "real_estate_agent",
    "advertising_agency",
    "industrial_equipment",
    "parking",
    "physical_therapy",
    "dentist",
    "religious_organization",
    "accountant",
    "print_media",
    "lawyer",
    "business_management_services",
    "engineering_services",
    "home_cleaning",
    "public_service_and_government",
    "social_service_organizations",
    "interior_design",
    "internet_service_provider",
    "financial_service",
    "home_developer",
    "automotive_repair",
    "health_and_medical",
    "architectural_designer",
    "freight_and_cargo_service",
    "marketing_agency",
    "broadcasting_media_production",
    "driving_school",
    "bank_credit_union",
    "central_government_office",
    "event_photography",
    "veterinarian",
    "business_advertising",
    "embassy",
    "hvac_services",
    "property_management",
    "industrial_company",
    "shipping_center",
    "graphic_designer",
    "community_center",
    "contractor",
    "auto_company",
    "real_estate_service",
    "commercial_industrial",
    "computer_hardware_company",
    "non_governmental_association",
    "topic_publisher",
    "electrician",
    "marketing_consultant",
    "automotive_dealer",
    "home_health_care",
    "post_office",
    "fire_department",
    "movie_television_studio",
    "home_service",
    "car_rental_agency",
    "tire_dealer_and_repair",
    "commercial_real_estate",
    "printing_services",
    "telecommunications_company",
    "taxi_service",
    "inspection_services",
    "lawyers",
    "government_offices",
    "marketing",
    "security_systems",
    "corporate_office",
    "pharmaceutical_companies",
    "prenatal_perinatal_care",
    "occupational_therapy",
    "divorce_and_family_law",
    "consultant_and_general_service",
    "professional_sports_team",
    "business_to_business_services",
    "environmental_and_ecological_services_for_businesses",
    "ambulance_and_ems_services",
    "massage_school",
    "osteopathic_physician",
    "business",
    "fire_protection_service",
    "patent_law",
    "media_agency",
    "automation_services",
    "civil_engineers",
    "tax_services",
    "collection_agencies",
    "local_and_state_government_offices",
    "structural_engineer",
    "public_health_clinic",
    "janitorial_services",
    "housing_authorities",
    "health_department",
    "abuse_and_addiction_treatment",
    "foster_care_services",
    "energy_management_and_conservation_consultants",
    "home_inspector",
    "federal_government_offices",
    "tax_law",
    "hearing_aids",
    "career_counseling",
    "secretarial_services",
    "it_consultant",
    "traffic_school",
    "real_estate_law",
    "electricity_supplier",
    "employment_law",
    "business_brokers",
    "data_recovery",
    "criminal_defense_law",
    "department_of_motor_vehicles",
    "health_insurance_office",
    "board_of_education_offices",
    "public_transportation",
    "paralegal_services",
    "appraisal_services",
    "human_resource_services",
    "religious_school",
    "hindu_temple",
    "buddhist_temple",
    "sikh_temple",
    "temple",
    "baptist_church",
    "plastic_fabrication_company",
    "landscape_architect",
    "demolition_service",
    "flooring_contractors",
    "elevator_service",
    "railroad_freight",
    "plastic_fabrication_company",
    "logging_services",
    "insulation_installation",
    "bathroom_remodeling",
    "home_organization",
    "bath_and_sink_repairs",
    "boat_service_and_repair",
    "prenatal_perinatal_care",
    "obstetrician_and_gynecologist",
    "allergist",
    "pediatrician",
    "audiologist",
    "periodontist",
    "orthodontist",
    "clinical_laboratories",
    "laboratory_equipment_supplier", 'senior_citizen_services', 'surgical_center', 'cleaning_services', 
    'dog_groomer', 'pet_sitting', 'dog_walkers',
    'web_designer', 'b2b_science_and_technology', 'b2b_textiles', 'mass_media', 'charity_organization', 
    'engine_repair_service', 'laboratory_testing', 'wholesaler', 'insurance_agency', 'employment_agencies', 
    'energy_company', 'merchandising_service', 'media_news_company', 'international_business_and_trade_services', 
    'business_to_business', 'rental_service', 'it_service_and_computer_repair', 'organization', 'roofing', 
    'recycling_center', 'courier_and_delivery_services', 'public_relations','nurse_practitioner', 'general_dentistry',
    'business_consulting', 'freight_forwarding_agency', 'copywriting_service', 'political_organization', 
    'political_party_office', 'legal_services', 'internet_marketing_service', 'medical_research_and_development', 
    'audiovisual_equipment_rental', 'rental_services', 'food_beverage_service_distribution', 'social_media_agency', 
    'b2b_electronic_equipment', 'car_inspector', 'armed_forces_branch', 'medical_center', 'surgical_appliances_and_supplies', 
    'social_and_human_services', 'private_association', 'public_utility_company', 'appliance_manufacturer', 
    'pest_control_service', 'chemical_plant', 'construction_management', 'building_contractor', 'exporters', 
    'b2b_oil_and_gas_extraction_and_services', 'agricultural_cooperatives', 'environmental_conservation_organization', 
    'video_film_production', 'distribution_services', 'party_and_event_planning', 'garbage_collection_service', 
    'travel_company', 'security_services', 'psychic', 'television_service_providers', 'telecommunications','travel_agents',
    'publicity_service', 'b2b_equipment_maintenance_and_repair', 'metal_materials_and_experts', 'masonry_concrete', 
    'metal_fabricator', 'printing_equipment_and_supply', 'b2b_cleaning_and_waste_management', 'audio_visual_production_and_design', 
    'paving_contractor', 'livestock_breeder', 'iron_and_steel_industry', 'steel_fabricators', 'printing_equipment_and_supply', 
    'professional_sports_league', 'translation_services', 'mortgage_broker', 'executive_search_consultants', 'government_services', 
    'credit_union', 'b2b_jewelers', 'hotel_supply_service', 'art_restoration', 'home_security', 'real_estate_investment', 
    'emergency_room', 'nurse_practitioner', 'occupational_safety', 'trusts', 'commissioned_artist', 'road_contractor', 
    'vehicle_shipping', 'mortgage_lender', 'civic_center', 'aircraft_manufacturer', 'blood_and_plasma_donation_center', 
    'mortgage_lender', 'credit_union', 'executive_search_consultants', 'financial_advising', 'business_consulting', 'lawyer', 
    'courthouse', 'jail_and_prison', 'fire_and_water_damage_restoration', 'eye_care_clinic', 'orthopedics', 'cosmetic_surgeon',
    'town_hall', 'court_house', 'mosque', 'catholic_church', 'evangelical_church', 'pentecostal_church', 'jehovahs_witness_kingdom_hall',
    'convents_and_monasteries', 'doctor', 'optometrist', 'plastic_surgeon','prosthodontist', 'pediatric_dentist',
    "damage_restoration",
    "motor_freight_trucking",
    "warehouses",
    "carpenter",
    "youth_organizations",
    "translating_and_interpreting_services",
    "hvac_supplier",
    "labor_union",
    "auto_glass_service",
    "funeral_services_and_cemeteries",
    "key_and_locksmith",
    "plumbing",
    "motorcycle_repair",
    "used_car_dealer",
    "auto_electrical_repair",
    "car_wash",
    "boat_rental_and_training",
    "importers",
    "investing",
    "architect",
    "shoe_repair",
    "biotechnology_company",
    "builder",
    "auction_house",
    "videographer",
    "environmental_conservation_and_ecological_organizations",
    "mining",
    "airline",
    "fireplace_service",
    "agriculture",
    "land_surveying",
    "forestry_service",
    "landscaping",
    "gardener",
    "tree_services",
    "chimney_sweep",
    "emissions_inspection",
    "natural_gas_supplier",
    "hydraulic_equipment_supplier",
    "boat_dealer",
    "boat_parts_and_accessories",
    "recreational_vehicle_dealer",
    "movers",
    "cremation_services",
    "housing_cooperative",
    "homeless_shelter",
    "coworking_space",
    "radio_and_television_commercials",
    "automotive_consultant",
    "electric_utility_provider",
    "tiling",
    "countertop_installation",
    "radio_station",
    "bookkeeper",
    "media_news_website",
    "energy_equipment_and_solution",
    "b2b_truck_equipment_parts_and_accessories",
    "water_supplier",
    "ev_charging_station",
    "awning_supplier",
    "cement_supplier",
    "glass_manufacturer",
    "plastic_manufacturer",
    "wheel_and_rim_repair",
    "digitizing_services",
    "auto_restoration_services",
    "piano_services",
    "farm_equipment_and_supply",
    "gold_buyer",
    "bartender",
    "airlines",
    "excavations_service",
    "wedding_planning",
    "religious",
    "pet_groomer",
    "dog_trainer",
    "horse_trainer",
    "taxidermist",
    "podiatrist",
    "ophthalmologist",
    'architect'
    "oral_surgeon",
    "maternity_centers"
],

  "Shopping & Retail": [
    "shopping",
    "clothing_store",
    "online_shop",
    "fashion",
    "furniture_store",
    "flowers_and_gifts_shop",
    "women's_clothing_store",
    "auto_detailing",
    "shopping_center",
    "sporting_goods",
    "home_improvement_store",
    "cosmetic_and_beauty_supplies",
    "jewelry_store",
    "bicycle_shop",
    "pet_services",
    "eyewear_and_optician",
    "building_supply_store",
    "automotive_parts_and_accessories",
    "electronics",
    "hardware_store",
    "retail",
    "bookstore",
    "sewing_and_alterations",
    "men's_clothing_store",
    "flea_market",
    "shoe_store",
    "department_store",
    "mobile_phone_store",
    "musical_instrument_store",
    "lighting_store",
    "antique_store",
    "liquor_store",
    "pet_store",
    "used_vintage_and_consignment",
    "fabric_store",
    "electrical_supply_store",
    "pop_up_shop",
    "fishmonger",
    "kitchen_supply_store",
    "lingerie_store",
    "screen_printing_t_shirt_printing",
    "sign_making",
    "restaurant_equipment_and_supply",
    "furniture_manufacturers",
    "dry_cleaning",
    "ski_and_snowboard_shop",
    "lumber_store",
    "outdoor_gear",
    "farmers_market",
    "chocolatier",
    "appliance_repair_service",
    "machine_shop",
    "pawn_shop",
    "jewelry_and_watches_manufacturer",
    "sand_and_gravel_supplier",
    "paint_store",
    "solar_installation",
    "e_cigarette_store",
    "brake_service_and_repair",
    "dental_supply_store",
    "paintball",
    "video_game_store",
    "pharmaceutical_products_wholesaler",
    "glass_and_mirror_sales_service",
    "auto_manufacturers_and_distributors",
    "rug_store",
    "luggage_store",
    "electronic_parts_supplier",
    "home_decor",
    "windows_installation",
    "aquatic_pet_store",
    "automotive_services_and_repair",
    "b2b_food_products",
    "business_office_supplies_and_stationery",
    "woodworking_supply_store",
    "metal_supplier",
    "comic_books_store",
    "packing_supply",
    "laundromat",
    "paper_mill",
    "canoe_and_kayak_hire_service",
    "oil_and_gas_field_equipment_and_services",
    "masonry_contractors",
    "costume_store",
    "wig_store",
    "scuba_diving_center",
    "book_magazine_distribution",
    "hunting_and_fishing_supplies",
    "wood_and_pulp",
    "tile_store",
    "bottled_water_company",
    "framing_store",
    "commercial_printer",
    "pet_breeder",
    "toy_store",
    "motorsports_store",
    "auto_upholstery",
    "patio_covers",
    "welding_supply_store",
    "truck_repair",
    "music_and_dvd_store",
    "deck_and_railing_sales_service",
    "truck_rentals",
    "leather_goods",
    "superstore",
    "commercial_refrigeration",
    "motorsport_vehicle_dealer",
    "propane_supplier",
    "trailer_rentals",
    "cards_and_stationery_store",
    "fertilizer_store",
    "awnings_and_blinds",
    "fabric_wholesaler",
    "yard_and_equipment_sales",
    "mobile_phone_repair",
    "rv_park",
    "outlet_store",
    "junk_removal_and_hauling",
    "junkyard",
    "logging_equipment_and_supplies",
    "e_commerce_service",
    "fence_and_gate_sales_service",
    "trailer_dealer",
    "machine_and_tool_rentals",
    "promotional_products_and_services",
    "car_window_tinting",
    "metals",
    "truck_dealer",
    "dental_supply_store",
    "heliports",
    "furniture_repair",
    "hat_shop",
    "window_treatment_store",
    "tools_wholesaler",
    "mattress_store",
    "candy_store",
    "logging_equipment_and_supplies",
    'perfume_store',
    "thrift_store",
    "fashion_accessories_store",
    "children's_clothing_store",
    "photography_store_and_services",
    "home_goods_store",
    "audio_visual_equipment_store",
    "boutique",
    "storage_facility",
    "self_storage_facility",
    "motorcycle_dealer",
    "carpet_store",
    "appliance_store",
    "computer_store",
    "auto_parts_and_supply_store",
    "auto_customization",
    "office_equipment",
    "discount_store",
    "florist",
    "bridal_shop",
    "vitamins_and_supplements",
    "sunglasses_store",
    "clothing_company",
    "sports_wear",
    "gift_shop",
    "books_mags_music_and_video",
    "custom_clothing",
    "hobby_shop",
    "home_and_garden",
    "swimwear_store",
    "newspaper_and_magazines_store",
    "pets",
    "stone_and_masonry",
    "souvenir_shop",
    "custom_t_shirt_store",
    "shades_and_blinds",
    "luggage_storage",
    "tire_shop",
    "reptile_shop",
    "home_theater_systems_stores",
    "skate_shop",
    "b2b_apparel"
  ],

  "Restaurant & Entertainment": [
    "restaurant",
    "cafe",
    "bar",
    "pizza_restaurant",
    "coffee_shop",
    "topic_concert_venue",
    "accommodation",
    "arts_and_entertainment",
    "theatre",
    "pub",
    "sushi_restaurant",
    "bakery",
    'library', 'cultural_center', 
    "burger_restaurant",
    "fast_food_restaurant",
    "sports_and_recreation_venue",
    "museum",
    "attractions_and_activities",
    "travel",
    "arts_and_crafts",
    "italian_restaurant",
    "pool_billiards",
    "chinese_restaurant",
    "travel_services",
    "music_production",
    "music_venue",
    "dance_club",
    "thai_restaurant",
    "sandwich_shop",
    "buffet_restaurant",
    "cinema",
    "himalayan_nepalese_restaurant",
    "golf_course",
    "caterer",
    "choir",
    "cafetaria",
    "art_museum",
    "eat_and_drink",
    "mexican_restaurant",
    "winery",
    "karaoke",
    "asian_restaurant",
    "japanese_restaurant",
    "indian_restaurant",
    "marina",
    "tours",
    "georgian_restaurant",
    "beer_bar",
    "smoothie_juice_bar",
    "ice_cream_shop",
    "doner_kebab",
    "greek_restaurant",
    "korean_restaurant",
    "salad_bar",
    "french_restaurant",
    "mediterranean_restaurant",
    "jazz_and_blues",
    "irish_pub",
    'art_gallery',
    "american_restaurant",
    "asian_fusion_restaurant",
    "soup_restaurant",
    "lebanese_restaurant",
    "restaurant_wholesale",
    "tapas_bar",
    "desserts",
    "food_stand",
    "hot_dog_restaurant",
    'portuguese_restaurant',
    "arcade",
    "comedy_club",
    "theatrical_productions",
    "hotel_bar",
    "food_delivery_service",
    "food_truck",
    "halal_restaurant",
    "spanish_restaurant",
    "persian_iranian_restaurant",
    "filipino_restaurant",
    "falafel_restaurant",
    "malaysian_restaurant",
    "texmex_restaurant",
    "comfort_food_restaurant",
    "russian_restaurant",
    "noodles_restaurant",
    "poke",
    "donuts",
    "ice_cream_and_frozen_yoghurt",
    "gelato",
    "hawaiian_restaurant",
    "painting",
    "sports_bar",
    "distillery",
    "sports_museum",
    "whiskey_bar",
    "coffee_roastery",
    "sake_bar",
    "afghan_restaurant",
    "german_restaurant",
    "czech_restaurant",
    "taco_restaurant",
    "kurdish_restaurant",
    "egyptian_restaurant",
    "peruvian_restaurant",
    "ukrainian_restaurant",
    "latin_american_restaurant",
    "syrian_restaurant",
    "indonesian_restaurant",
    "dim_sum_restaurant",
    "cupcake_shop",
    "science_museum",
    "civilization_museum",
    "history_museum",
    "gay_bar",
    "stadium_arena",
    "circus", "go_kart_club",
    "landmark_and_historical_building",
    "planetarium", 'vegetarian_restaurant', 'casino', 'wine_bar', 'bar_and_grill_restaurant', 
    'scandinavian_restaurant', 'cocktail_bar', 
    'breakfast_and_brunch_restaurant', 'vietnamese_restaurant', 'delicatessen', 
    'brewery', 'european_restaurant', 'barbecue_restaurant', 
    'ice_skating_rink', 'diner', 'seafood_restaurant', 'steakhouse', 'bubble_tea',
    'turkish_restaurant', 'chicken_restaurant', 'middle_eastern_restaurant', 
    'beer_garden', 'gastropub', 'lounge', 'tea_room', 'restaurant', 
    'fast_food', 'cafe', 'food_court', 'night_club', 'bowling_alley', 'arcade', 
    'amusement_park', 'water_park', 'miniature_golf_course', 'ski_resort', 'resort',
    'hostel', 'campground', 'movie_theater', 'opera_and_ballet', 
    'theaters_and_performance_venues', 'concert_hall', 'music_venue', 'dance_club', 
    'karaoke_bar', 'escape_rooms', 'video_game_arcade', 'party_and_event_planning',
    'party_supply', 'dinner_theater', 'food_tours', 'food_and_beverage_consultant', 
    'food'
  ],

  "Well-being & Lifestyle": [
    "beauty_salon",
    "spas",
    "gym",
    "park",
    "hospital",
    "barber",
    "day_care_preschool",
    "sports_club_and_league",
    "beauty_and_spa",
    "retirement_home",
    "pharmacy",
    "public_plaza",
    "naturopathic_holistic",
    "yoga_studio",
    "dance_school",
    "music_school",
    "pilates_studio",
    "counseling_and_mental_health",
    "fitness_trainer",
    "chiropractor",
    "meditation_center",
    "medical_supply",
    "medical_service_organizations",
    "occupational_therapy",
    "pet_boarding",
    "tanning_salon",
    "massage_therapy",
    "weight_loss_center",
    "nutritionist",
    "swimming_instructor",
    "massage_school",
    "reflexology",
    "bike_rentals",
    "piercing",
    "psychiatrist",
    "hair_removal",
    'skate_park',
    "nail_salon",
    "sugaring",
    "personal_care_service",
    "makeup_artist",
    "dog_park",
    "paddleboarding_center",
    "medical_spa",
    "aromatherapy",
    "tattoo_and_piercing",
    "osteopath",
    "scuba_diving_instruction",
    "alternative_medicine",
    "sex_therapist",
    "foot_care",
    "equestrian_facility",
    "health_market",
    "family_practice", 
    'martial_arts_club', 
    'assisted_living_facility', 
    "active_life",
    'psychologist', 
    "national_park",
    'life_coach', 'massage', 'hair_salon', 
    'acupuncture',
    'psychotherapist', 
    'cosmetic_dentist', 
    "rock_climbing_spot",
    'speech_therapist', 
    'alcohol_and_drug_treatment_centers', 
    'acupuncture', 'hair_stylist', 
    'disability_services_and_support_organization', 'beauty_product_supplier', 'massage', 'well_drilling', 
    'swimming_pool',
    "surfing",
    "hiking_trail",
    'sauna', 'gymnastics_center', 'sports_and_fitness_instruction',
    'hair_supply_stores', 'fitness_center', 'yoga_studio', 'wellness_center', 'spa',
    "tennis_court",
    "soccer_stadium",
    "hockey_arena",
    "disc_golf_course",
    "soccer_field",
    "playground",
    "basketball_court",
    "baseball_field",
    "racquetball_court",
    "squash_court",
  ],

  "Educational Facilities": [
    "school",
    "college_university",
    "elementary_school",
    "education",
    "preschool",
    "campus_building",
    "high_school",
    "public_school",
    "private_school",
    "flight_school",
    "university",
    "college",
    "preschool",
    "education_buildings",
    "cooking_school",
    "middle_school",
    "educational_research_institute",
    "first_aid_class",
    "educational_camp",
    "computer_coaching",
    "writing_service",
    "medical_school",
    "bartending_school",
    "child_care_and_day_care",
    "educational_services",
    "sports_psychologist",
    'nursery_and_gardening', 'tutoring_center', 
    'language_school', 'art_school', 'specialty_school', 'vocational_and_technical_school'
  
  ],

  "Grocery Stores & Supermarkets": [
    "grocery_store",
    "supermarket",
    "wholesale_store",
    "convenience_store",
    "butcher_shop",
    "grocery_stores",
    "supermarkets",
    "convenience_stores",
    "wholesale_stores",
    "farmers_market",
    "fruits_and_vegetables",
    "ethical_grocery",
    "cheese_shop",
    "specialty_grocery_store",
    "wholesale_grocer",
    "produce_wholesaler",
    "beverage_supplier",
    'health_food_store',
    "organic_grocery_store",
    'korean_grocery_store',
    "pasta_shop",
    "korean_grocery_store"
  ],

  "Uncategorized": [
    "transportation",
    "hotel",
    "gas_station",
    "beach",
    "atms",
    "car_dealer",
    "automotive",
    "train_station",
    "lake",
    "structure_and_geography",
    "airport",
    "river",
    "monument",
    "nature_reserve",
    "cottage",
    "bridge",
    "currency_exchange",
    "water_treatment_equipment_and_services",
    "zoo",
    "race_track",
    "kids_recreation_and_party",
    "apartments",
    "ferry_boat_company",
    "wildlife_sanctuary",
    "b2b_food_products",
    "heliports",
    "oil_and_gas_field_equipment_and_services",
    "rv_park",
    "logging_services",
    "junkyard",
    "junk_removal_and_hauling",
    "e_commerce_service",
    "promotional_products_and_services",
    'airport_lounge',
    'public_toilet', 
    'airport_terminal',
    'armed_forces_branch', 
    'police_department',
    'food_safety_training',
    "holiday_rental_home",
    "service_apartments",
    "bed_and_breakfast",
    "lodge",
    "cave"  
  ]}
